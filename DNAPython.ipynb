# %%
# !pip install biopython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: biopython in c:\users\icard\appdata\roaming\python\python312\site-packages (1.84)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from biopython) (1.26.4)

# %%
import pandas as pd
import time
from Bio import Entrez

def fetch_snp_info(rsid):
    try:
        Entrez.email = "ilcardenas26@gmail.com"  # Replace with your email
        handle = Entrez.efetch(db="snp", id=rsid, rettype="docset", retmode="text")
        time.sleep(3)  # Be mindful of API rate limits
        return handle.read()
    except Exception as e:
        print(f"Error fetching data for {rsid}: {e}")
        return None

# Read your file with rsIDs
file_path = "AncestryDNA.txt"
df = pd.read_csv(file_path, delimiter="\t")

# Ensure 'snp_info' column exists
if 'snp_info' not in df.columns:
    df['snp_info'] = None

# Fetch and save data row by row
output_file = "snp_info_output.csv"

# %%
for index, row in df.iterrows():
    if pd.isna(row['snp_info']):  # Skip already fetched rows
        for row2 in df.iterrows():
            if row2[4].isna(): 
                rsid = row['rsid']
                print(f"Fetching data for {rsid}...")
                snp_info = fetch_snp_info(rsid)
                df.at[index, 'snp_info'] = snp_info
                # Save after each fetch
                df.to_csv(output_file, index=False)
                print(f"Saved progress after {rsid}.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 4
#       2 if pd.isna(row['snp_info']):  # Skip already fetched rows
#       3     for row2 in df.iterrows():
# ----> 4         if row2[4].isna():
#       5             rsid = row['rsid']
#       6             print(f"Fetching data for {rsid}...")
#
# IndexError: tuple index out of range

# %%
import csv
import time
from Bio import Entrez

def fetch_snp_info(rsid):
    try:
        Entrez.email = "ilcardenas26@gmail.com"
        handle = Entrez.efetch(db="snp", id=rsid, rettype="docset", retmode="text")
        time.sleep(3)
        return handle.read()
    except Exception as e:
        print(f"Error fetching data for {rsid}: {e}")
        return None

# Input and output files
input_file = "AncestryDNA.txt"
output_file = "snp_info_output.csv"

# Process line by line
with open(input_file, "r") as infile, open(output_file, "a", newline="") as outfile:
    reader = csv.DictReader(infile, delimiter="\t")
    fieldnames = reader.fieldnames + ["snp_info"]
    writer = csv.DictWriter(outfile, fieldnames=fieldnames)

    # Write header if output file is empty
    if outfile.tell() == 0:
        writer.writeheader()

    for row in reader:
        if "snp_info" not in row or not row["snp_info"]:  # Skip if already fetched
            print(f"Fetching data for {row['rsid']}...")
            row["snp_info"] = fetch_snp_info(row["rsid"])
            writer.writerow(row)
            print(f"Saved {row['rsid']} to file.")
# Out:
# Fetching data for rs3131972...
# Saved rs3131972 to file.
# Fetching data for rs114525117...
# Saved rs114525117 to file.
# Fetching data for rs4040617...
# Saved rs4040617 to file.
# Fetching data for rs141175086...
# Saved rs141175086 to file.
# Fetching data for rs115093905...
# Saved rs115093905 to file.
# Fetching data for rs11240777...
# Saved rs11240777 to file.
# Fetching data for rs6681049...
# Saved rs6681049 to file.
# Fetching data for rs4422948...
# Saved rs4422948 to file.
# Fetching data for rs57494724...
# Saved rs57494724 to file.
# Fetching data for rs4475691...
# Saved rs4475691 to file.
# Fetching data for rs6657440...
# Saved rs6657440 to file.
# Fetching data for rs4970461...
# Saved rs4970461 to file.
# Fetching data for rs7537756...
# Saved rs7537756 to file.
# Fetching data for rs13302982...
# Saved rs13302982 to file.
# Fetching data for rs2880024...
# Saved rs2880024 to file.
# Fetching data for rs74047407...
# Saved rs74047407 to file.
# Fetching data for rs1110052...
# Saved rs1110052 to file.
# Fetching data for rs7523549...
# Saved rs7523549 to file.
# Fetching data for rs2272756...
# Saved rs2272756 to file.
# Fetching data for rs3748597...
# Saved rs3748597 to file.
# Fetching data for rs13302957...
# Saved rs13302957 to file.
# Fetching data for rs13303106...
# Saved rs13303106 to file.
# Fetching data for rs13303010...
# Saved rs13303010 to file.
# Fetching data for rs200468119...
# Saved rs200468119 to file.
# Fetching data for rs6696281...
# Saved rs6696281 to file.
# Fetching data for rs6696609...
# Saved rs6696609 to file.
# Fetching data for rs28391282...
# Saved rs28391282 to file.
# Fetching data for rs28477686...
# Saved rs28477686 to file.
# Fetching data for rs6660139...
# Saved rs6660139 to file.
# Fetching data for rs13303118...
# Saved rs13303118 to file.
# Fetching data for rs2341354...
# Saved rs2341354 to file.
# Fetching data for rs4970414...
# Saved rs4970414 to file.
# Fetching data for rs116781904...
# Saved rs116781904 to file.
# Fetching data for rs78164078...
# Saved rs78164078 to file.
# Fetching data for rs6665000...
# Saved rs6665000 to file.
# Fetching data for rs2341362...
# Saved rs2341362 to file.
# Fetching data for rs9777703...
# Saved rs9777703 to file.
# Fetching data for rs1891910...
# Saved rs1891910 to file.
# Fetching data for rs35940137...
# Saved rs35940137 to file.
# Fetching data for rs3128117...
# Saved rs3128117 to file.
# Fetching data for rs2465126...
# Saved rs2465126 to file.
# Fetching data for rs2341365...
# Saved rs2341365 to file.
# Fetching data for rs786201005...
# Saved rs786201005 to file.
# Fetching data for rs8997...
# Saved rs8997 to file.
# Fetching data for rs672601312...
# Saved rs672601312 to file.
# Fetching data for rs756623659...
# Saved rs756623659 to file.
# Fetching data for rs6657048...
# Saved rs6657048 to file.
# Fetching data for rs28591569...
# Saved rs28591569 to file.
# Fetching data for rs2710888...
# Saved rs2710888 to file.
# Fetching data for rs2488993...
# Error fetching data for rs2488993: HTTP Error 400: Bad Request
# Saved rs2488993 to file.
# Fetching data for rs587777299...
# Error fetching data for rs587777299: HTTP Error 400: Bad Request
# Saved rs587777299 to file.
# Fetching data for rs2710875...
# Saved rs2710875 to file.
# Fetching data for rs143324306...
# Saved rs143324306 to file.
# Fetching data for rs2465128...
# Saved rs2465128 to file.
# Fetching data for rs150132566...
# Saved rs150132566 to file.
# Fetching data for rs536657086...
# Saved rs536657086 to file.
# Fetching data for rs9442391...
# Saved rs9442391 to file.
# Fetching data for rs2275813...
# Saved rs2275813 to file.
# Fetching data for rs2275811...
# Saved rs2275811 to file.
# Fetching data for rs17160775...
# Saved rs17160775 to file.
# Fetching data for rs764160563...
# Saved rs764160563 to file.
# Fetching data for rs17160776...
# Saved rs17160776 to file.
# Fetching data for rs199476396...
# Saved rs199476396 to file.
# Fetching data for rs587777298...
# Saved rs587777298 to file.
# Fetching data for rs144245019...
# Saved rs144245019 to file.
# Fetching data for rs763818876...
# Saved rs763818876 to file.
# Fetching data for rs9803031...
# Saved rs9803031 to file.
# Fetching data for rs4275402...
# Saved rs4275402 to file.
# Fetching data for rs2465136...
# Saved rs2465136 to file.
# Fetching data for rs9331226...
# Saved rs9331226 to file.
# Fetching data for rs2488991...
# Saved rs2488991 to file.
# Fetching data for rs3934834...
# Saved rs3934834 to file.
# Fetching data for rs3766192...
# Saved rs3766192 to file.
# Fetching data for rs3766191...
# Saved rs3766191 to file.
# Fetching data for rs9442372...
# Saved rs9442372 to file.
# Fetching data for rs10907177...
# Saved rs10907177 to file.
# Fetching data for rs3737728...
# Saved rs3737728 to file.
# Fetching data for rs9442400...
# Saved rs9442400 to file.
# Fetching data for rs6687776...
# Saved rs6687776 to file.
# Fetching data for rs6671356...
# Saved rs6671356 to file.
# Fetching data for rs7548798...
# Saved rs7548798 to file.
# Fetching data for rs11807848...
# Saved rs11807848 to file.
# Fetching data for rs12757754...
# Saved rs12757754 to file.
# Fetching data for rs9442373...
# Saved rs9442373 to file.
# Fetching data for rs2298217...
# Saved rs2298217 to file.
# Fetching data for rs4072537...
# Saved rs4072537 to file.
# Fetching data for rs9442358...
# Saved rs9442358 to file.
# Fetching data for rs11260603...
# Saved rs11260603 to file.
# Fetching data for rs4970362...
# Saved rs4970362 to file.
# Fetching data for rs61768477...
# Saved rs61768477 to file.
# Fetching data for rs9442385...
# Saved rs9442385 to file.
# Fetching data for rs1891905...
# Saved rs1891905 to file.
# Fetching data for rs6670693...
# Saved rs6670693 to file.
# Fetching data for rs4970420...
# Saved rs4970420 to file.
# Fetching data for rs4970421...
# Saved rs4970421 to file.
# Fetching data for rs11260542...
# Saved rs11260542 to file.
# Fetching data for rs61768483...
# Saved rs61768483 to file.
# Fetching data for rs9442387...
# Saved rs9442387 to file.
# Fetching data for rs6671609...
# Saved rs6671609 to file.
# Fetching data for rs72631898...
# Saved rs72631898 to file.
# Fetching data for rs1320571...
# Saved rs1320571 to file.
# Fetching data for rs3813204...
# Saved rs3813204 to file.
# Fetching data for rs11260549...
# Saved rs11260549 to file.
# Fetching data for rs10907175...
# Saved rs10907175 to file.
# Fetching data for rs58004717...
# Saved rs58004717 to file.
# Fetching data for rs3819001...
# Saved rs3819001 to file.
# Fetching data for rs1815606...
# Saved rs1815606 to file.
# Fetching data for rs868275021...
# Saved rs868275021 to file.
# Fetching data for rs867377314...
# Saved rs867377314 to file.
# Fetching data for rs587777075...
# Saved rs587777075 to file.
# Fetching data for rs11721...
# Saved rs11721 to file.
# Fetching data for rs12036216...
# Saved rs12036216 to file.
# Fetching data for rs2887286...
# Saved rs2887286 to file.
# Fetching data for rs3813199...
# Saved rs3813199 to file.
# Fetching data for rs6603781...
# Saved rs6603781 to file.
# Fetching data for rs7515488...
# Saved rs7515488 to file.
# Fetching data for rs397514722...
# Saved rs397514722 to file.
# Fetching data for rs397514718...
# Saved rs397514718 to file.
# Fetching data for rs397514723...
# Saved rs397514723 to file.
# Fetching data for rs397514724...
# Saved rs397514724 to file.
# Fetching data for rs397514717...
# Saved rs397514717 to file.
# Fetching data for rs786200939...
# Saved rs786200939 to file.
# Fetching data for rs397514721...
# Saved rs397514721 to file.
# Fetching data for rs6697886...
# Saved rs6697886 to file.
# Fetching data for rs6675798...
# Saved rs6675798 to file.
# Fetching data for rs113729379...
# Saved rs113729379 to file.
# Fetching data for rs6657544...
# Saved rs6657544 to file.
# Fetching data for rs3818646...
# Saved rs3818646 to file.
# Fetching data for rs11804831...
# Saved rs11804831 to file.
# Fetching data for rs115272858...
# Saved rs115272858 to file.
# Fetching data for rs11260570...
# Saved rs11260570 to file.
# Fetching data for rs4018608...
# Saved rs4018608 to file.
# Fetching data for rs6667923...
# Saved rs6667923 to file.
# Fetching data for rs6685064...
# Saved rs6685064 to file.
# Fetching data for rs1262894...
# Saved rs1262894 to file.
# Fetching data for rs2144440...
# Saved rs2144440 to file.
# Fetching data for rs621668...
# Saved rs621668 to file.
# Fetching data for rs1739855...
# Saved rs1739855 to file.
# Fetching data for rs12410087...
# Saved rs12410087 to file.
# Fetching data for rs3766182...
# Saved rs3766182 to file.
# Fetching data for rs12142199...
# Saved rs12142199 to file.
# Fetching data for rs1886773...
# Saved rs1886773 to file.
# Fetching data for rs3845293...
# Saved rs3845293 to file.
# Fetching data for rs148629756...
# Saved rs148629756 to file.
# Fetching data for rs35424002...
# Saved rs35424002 to file.
# Fetching data for rs797044837...
# Saved rs797044837 to file.
# Fetching data for rs797044839...
# Saved rs797044839 to file.
# Fetching data for rs797044835...
# Saved rs797044835 to file.
# Fetching data for rs797044834...
# Saved rs797044834 to file.
# Fetching data for rs797044836...
# Saved rs797044836 to file.
# Fetching data for rs3855955...
# Saved rs3855955 to file.
# Fetching data for rs186507655...
# Saved rs186507655 to file.
# Fetching data for rs374879755...
# Saved rs374879755 to file.
# Fetching data for rs17160669...
# Saved rs17160669 to file.
# Fetching data for rs150194697...
# Saved rs150194697 to file.
# Fetching data for rs2649588...
# Saved rs2649588 to file.
# Fetching data for rs1240747...
# Saved rs1240747 to file.
# Fetching data for rs1240743...
# Saved rs1240743 to file.
# Fetching data for rs35242196...
# Saved rs35242196 to file.
# Fetching data for rs1240708...
# Saved rs1240708 to file.
# Fetching data for rs111876693...
# Saved rs111876693 to file.
# Fetching data for rs140521637...
# Saved rs140521637 to file.
# Fetching data for rs12089560...
# Saved rs12089560 to file.
# Fetching data for rs873927...
# Saved rs873927 to file.
# Fetching data for rs3843249...
# Saved rs3843249 to file.
# Fetching data for rs1312568...
# Saved rs1312568 to file.
# Fetching data for rs1240732...
# Saved rs1240732 to file.
# Fetching data for rs819980...
# Saved rs819980 to file.
# Fetching data for rs6690515...
# Saved rs6690515 to file.
# Fetching data for rs6669795...
# Saved rs6669795 to file.
# Fetching data for rs12032637...
# Saved rs12032637 to file.
# Fetching data for rs606231455...
# Saved rs606231455 to file.
# Fetching data for rs606231451...
# Saved rs606231451 to file.
# Fetching data for rs606231452...
# Saved rs606231452 to file.
# Fetching data for rs606231453...
# Saved rs606231453 to file.
# Fetching data for rs606231454...
# Saved rs606231454 to file.
# Fetching data for rs3118505...
# Saved rs3118505 to file.
# Fetching data for rs1571149...
# Saved rs1571149 to file.
# Fetching data for rs1571150...
# Fetching data for rs557224253...
# Saved rs557224253 to file.
# Fetching data for rs28508199...
# Saved rs28508199 to file.
# Fetching data for rs2144687...
# Saved rs2144687 to file.
# Fetching data for rs2803316...
# Saved rs2803316 to file.
# Fetching data for rs2803329...
# Saved rs2803329 to file.
# Fetching data for rs2262190...
# Saved rs2262190 to file.
# Fetching data for rs3820011...
# Saved rs3820011 to file.
# Fetching data for rs28549710...
# Saved rs28549710 to file.
# Fetching data for rs2474454...
# Saved rs2474454 to file.
# Fetching data for rs13303002...
# Saved rs13303002 to file.
# Fetching data for rs7523728...
# Saved rs7523728 to file.
# Fetching data for rs16824588...
# Error fetching data for rs16824588: HTTP Error 400: Bad Request
# Saved rs16824588 to file.
# Fetching data for rs16824605...
# Saved rs16824605 to file.
# Fetching data for rs4648745...
# Saved rs4648745 to file.
# Fetching data for rs61776990...
# Saved rs61776990 to file.
# Fetching data for rs4648747...
# Saved rs4648747 to file.
# Fetching data for rs3795283...
# Saved rs3795283 to file.
# Fetching data for rs4350140...
# Saved rs4350140 to file.
# Fetching data for rs13303332...
# Saved rs13303332 to file.
# Fetching data for rs6661597...
# Saved rs6661597 to file.
# Fetching data for rs55780084...
# Saved rs55780084 to file.
# Fetching data for rs6605081...
# Saved rs6605081 to file.
# Fetching data for rs6656398...
# Saved rs6656398 to file.
# Fetching data for rs10436728...
# Saved rs10436728 to file.
# Fetching data for rs13303016...
# Saved rs13303016 to file.
# Fetching data for rs13303344...
# Saved rs13303344 to file.
# Fetching data for rs28603108...
# Saved rs28603108 to file.
# Fetching data for rs121434580...
# Saved rs121434580 to file.
# Fetching data for rs55833012...
# Saved rs55833012 to file.
# Fetching data for rs2376803...
# Saved rs2376803 to file.
# Fetching data for rs3795277...
# Saved rs3795277 to file.
# Fetching data for rs4648795...
# Saved rs4648795 to file.
# Fetching data for rs35020387...
# Saved rs35020387 to file.
# Fetching data for rs2803309...
# Saved rs2803309 to file.
# Fetching data for rs1878745...
# Saved rs1878745 to file.
# Fetching data for rs2678939...
# Saved rs2678939 to file.
# Fetching data for rs6663158...
# Saved rs6663158 to file.
# Fetching data for rs2254669...
# Saved rs2254669 to file.
# Fetching data for rs28523336...
# Saved rs28523336 to file.
# Fetching data for rs16824752...
# Saved rs16824752 to file.
# Fetching data for rs2803310...
# Saved rs2803310 to file.
# Fetching data for rs6701689...
# Saved rs6701689 to file.
# Fetching data for rs2459994...
# Saved rs2459994 to file.
# Fetching data for rs12755035...
# Saved rs12755035 to file.
# Fetching data for rs3128326...
# Saved rs3128326 to file.
# Fetching data for rs884080...
# Saved rs884080 to file.
# Fetching data for rs10910030...
# Saved rs10910030 to file.
# Fetching data for rs12410859...
# Saved rs12410859 to file.
# Fetching data for rs4648807...
# Saved rs4648807 to file.
# Fetching data for rs4648808...
# Saved rs4648808 to file.
# Fetching data for rs6603813...
# Saved rs6603813 to file.
# Fetching data for rs925905...
# Saved rs925905 to file.
# Fetching data for rs56260599...
# Saved rs56260599 to file.
# Fetching data for rs3107153...
# Saved rs3107153 to file.
# Fetching data for rs3128291...
# Fetching data for rs880801...
# Saved rs880801 to file.
# Fetching data for rs947354...
# Saved rs947354 to file.
# Fetching data for rs56365936...
# Saved rs56365936 to file.
# Fetching data for rs12080677...
# Saved rs12080677 to file.
# Fetching data for rs10909973...
# Saved rs10909973 to file.
# Fetching data for rs2794340...
# Saved rs2794340 to file.
# Fetching data for rs2821050...
# Saved rs2821050 to file.
# Fetching data for rs10909974...
# Saved rs10909974 to file.
# Fetching data for rs12139206...
# Saved rs12139206 to file.
# Fetching data for rs2794320...
# Saved rs2794320 to file.
# Fetching data for rs4648527...
# Saved rs4648527 to file.
# Fetching data for rs6697749...
# Saved rs6697749 to file.
# Fetching data for rs7544357...
# Saved rs7544357 to file.
# Fetching data for rs2794327...
# Saved rs2794327 to file.
# Fetching data for rs2821025...
# Saved rs2821025 to file.
# Fetching data for rs2821023...
# Saved rs2821023 to file.
# Fetching data for rs56770023...
# Saved rs56770023 to file.
# Fetching data for rs35701577...
# Saved rs35701577 to file.
# Fetching data for rs10909986...
# Saved rs10909986 to file.
# Fetching data for rs34222941...
# Saved rs34222941 to file.
# Fetching data for rs4648530...
# Saved rs4648530 to file.
# Fetching data for rs4648398...
# Saved rs4648398 to file.
# Fetching data for rs12405423...
# Saved rs12405423 to file.
# Fetching data for rs6693192...
# Saved rs6693192 to file.
# Fetching data for rs4364818...
# Saved rs4364818 to file.
# Fetching data for rs10909989...
# Saved rs10909989 to file.
# Fetching data for rs10909990...
# Saved rs10909990 to file.
# Fetching data for rs12757620...
# Saved rs12757620 to file.
# Fetching data for rs34128889...
# Saved rs34128889 to file.
# Fetching data for rs4276857...
# Saved rs4276857 to file.
# Fetching data for rs1128474...
# Saved rs1128474 to file.
# Fetching data for rs2821007...
# Saved rs2821007 to file.
# Fetching data for rs7528494...
# Saved rs7528494 to file.
# Fetching data for rs60206806...
# Saved rs60206806 to file.
# Fetching data for rs12408890...
# Saved rs12408890 to file.
# Fetching data for rs74224224...
# Saved rs74224224 to file.
# Fetching data for rs1004650...
# Saved rs1004650 to file.
# Fetching data for rs6697769...
# Saved rs6697769 to file.
# Fetching data for rs10910003...
# Saved rs10910003 to file.
# Fetching data for rs2224718...
# Saved rs2224718 to file.
# Fetching data for rs4648545...
# Saved rs4648545 to file.
# Fetching data for rs3765692...
# Saved rs3765692 to file.
# Fetching data for rs7523732...
# Saved rs7523732 to file.
# Fetching data for rs1009345...
# Saved rs1009345 to file.
# Fetching data for rs3765695...
# Saved rs3765695 to file.
# Fetching data for rs3765696...
# Saved rs3765696 to file.
# Fetching data for rs56255778...
# Saved rs56255778 to file.
# Fetching data for rs3765702...
# Saved rs3765702 to file.
# Fetching data for rs3765703...
# Saved rs3765703 to file.
# Fetching data for rs10910008...
# Saved rs10910008 to file.
# Fetching data for rs3765705...
# Saved rs3765705 to file.
# Fetching data for rs3765716...
# Saved rs3765716 to file.
# Fetching data for rs1885872...
# Saved rs1885872 to file.
# Fetching data for rs3765725...
# Saved rs3765725 to file.
# Fetching data for rs3765731...
# Saved rs3765731 to file.
# Fetching data for rs3765736...
# Saved rs3765736 to file.
# Fetching data for rs6424089...
# Saved rs6424089 to file.
# Fetching data for rs6424090...
# Saved rs6424090 to file.
# Fetching data for rs3765761...
# Saved rs3765761 to file.
# Fetching data for rs3819967...
# Saved rs3819967 to file.
# Fetching data for rs3765764...
# Saved rs3765764 to file.
# Fetching data for rs3765766...
# Saved rs3765766 to file.
# Fetching data for rs747827...
# Saved rs747827 to file.
# Fetching data for rs12731705...
# Saved rs12731705 to file.
# Fetching data for rs2146658...
# Saved rs2146658 to file.
# Fetching data for rs12095248...
# Saved rs12095248 to file.
# Fetching data for rs11589885...
# Saved rs11589885 to file.
# Fetching data for rs1885865...
# Saved rs1885865 to file.
# Fetching data for rs4648553...
# Saved rs4648553 to file.
# Fetching data for rs1181867...
# Saved rs1181867 to file.
# Fetching data for rs7515164...
# Saved rs7515164 to file.
# Fetching data for rs3737589...
# Saved rs3737589 to file.
# Fetching data for rs4648554...
# Saved rs4648554 to file.
# Fetching data for rs76597070...
# Saved rs76597070 to file.
# Fetching data for rs1181888...
# Saved rs1181888 to file.
# Fetching data for rs75920155...
# Saved rs75920155 to file.
# Fetching data for rs1181883...
# Saved rs1181883 to file.
# Fetching data for rs10910024...
# Saved rs10910024 to file.
# Fetching data for rs1181878...
# Saved rs1181878 to file.
# Fetching data for rs1181877...
# Saved rs1181877 to file.
# Fetching data for rs1181875...
# Saved rs1181875 to file.
# Fetching data for rs1181874...
# Saved rs1181874 to file.
# Fetching data for rs10910025...
# Saved rs10910025 to file.
# Fetching data for rs1175549...
# Saved rs1175549 to file.
# Fetching data for rs2799182...
# Saved rs2799182 to file.
# Fetching data for rs8379...
# Saved rs8379 to file.
# Fetching data for rs8520...
# Saved rs8520 to file.
# Fetching data for rs12563491...
# Saved rs12563491 to file.
# Fetching data for rs2298227...
# Saved rs2298227 to file.
# Fetching data for rs12728911...
# Saved rs12728911 to file.
# Fetching data for rs6662706...
# Saved rs6662706 to file.
# Fetching data for rs869025278...
# Saved rs869025278 to file.
# Fetching data for rs9424290...
# Saved rs9424290 to file.
# Fetching data for rs12759497...
# Saved rs12759497 to file.
# Fetching data for rs6663840...
# Saved rs6663840 to file.
# Fetching data for rs9424310...
# Saved rs9424310 to file.
# Fetching data for rs34839626...
# Saved rs34839626 to file.
# Fetching data for rs2275831...
# Saved rs2275831 to file.
# Fetching data for rs869025276...
# Saved rs869025276 to file.
# Fetching data for rs2275822...
# Saved rs2275822 to file.
# Fetching data for rs374574638...
# Saved rs374574638 to file.
# Fetching data for rs10492943...
# Saved rs10492943 to file.
# Fetching data for rs4564078...
# Saved rs4564078 to file.
# Fetching data for rs4648426...
# Saved rs4648426 to file.
# Fetching data for rs10797348...
# Saved rs10797348 to file.
# Fetching data for rs72848469...
# Saved rs72848469 to file.
# ...
# Fetching data for rs3131529...
# Saved rs3131529 to file.
# Fetching data for rs899378...
# Saved rs899378 to file.
# Fetching data for rs12127677...
# Saved rs12127677 to file.
# Fetching data for rs9425897...
# Saved rs9425897 to file.
# Fetching data for rs12043450...
# Saved rs12043450 to file.
# Fetching data for rs7544044...
# Saved rs7544044 to file.
# Fetching data for rs1865892...
# Saved rs1865892 to file.
# Fetching data for rs61771416...
# Saved rs61771416 to file.
# Fetching data for rs9425986...
# Saved rs9425986 to file.
# Fetching data for rs7551631...
# Saved rs7551631 to file.
# Fetching data for rs61771419...
# Saved rs61771419 to file.
# Fetching data for rs10914862...
# Saved rs10914862 to file.
# Fetching data for rs6665353...
# Saved rs6665353 to file.
# Fetching data for rs12048816...
# Saved rs12048816 to file.
# Fetching data for rs1898290...
# Saved rs1898290 to file.
# Fetching data for rs2196541...
# Saved rs2196541 to file.
# Fetching data for rs1382600...
# Saved rs1382600 to file.
# Fetching data for rs705217...
# Saved rs705217 to file.
# Fetching data for rs1065965...
# Saved rs1065965 to file.
# Fetching data for rs11581276...
# Saved rs11581276 to file.
# Fetching data for rs6425876...
# Saved rs6425876 to file.
# Fetching data for rs1771386...
# Saved rs1771386 to file.
# Fetching data for rs9426003...
# Saved rs9426003 to file.
# Fetching data for rs9662615...
# Saved rs9662615 to file.
# Fetching data for rs771150...
# Saved rs771150 to file.
# Fetching data for rs705210...
# Saved rs705210 to file.
# Fetching data for rs796405...
# Saved rs796405 to file.
# Fetching data for rs771138...
# Saved rs771138 to file.
# Fetching data for rs771132...
# Saved rs771132 to file.
# Fetching data for rs11590546...
# Saved rs11590546 to file.
# Fetching data for rs12755908...
# Saved rs12755908 to file.
# Fetching data for rs10914880...
# Saved rs10914880 to file.
# Fetching data for rs12145664...
# Saved rs12145664 to file.
# Fetching data for rs4652992...
# Saved rs4652992 to file.
# Fetching data for rs7552457...
# Saved rs7552457 to file.
# Fetching data for rs10493055...
# Saved rs10493055 to file.
# Fetching data for rs771122...
# Saved rs771122 to file.
# Fetching data for rs297789...
# Saved rs297789 to file.
# Fetching data for rs34770980...
# Saved rs34770980 to file.
# Fetching data for rs61769841...
# Saved rs61769841 to file.
# Fetching data for rs6662000...
# Saved rs6662000 to file.
# Fetching data for rs12073716...
# Saved rs12073716 to file.
# Fetching data for rs4653400...
# Saved rs4653400 to file.
# Fetching data for rs750572...
# Saved rs750572 to file.
# Fetching data for rs297783...
# Saved rs297783 to file.
# Fetching data for rs6689801...
# Saved rs6689801 to file.
# Fetching data for rs2994598...
# Saved rs2994598 to file.
# Fetching data for rs2792928...
# Saved rs2792928 to file.
# Fetching data for rs1771374...
# Saved rs1771374 to file.
# Fetching data for rs297804...
# Saved rs297804 to file.
# Fetching data for rs13375367...
# Saved rs13375367 to file.
# Fetching data for rs297802...
# Saved rs297802 to file.
# Fetching data for rs11577248...
# Saved rs11577248 to file.
# Fetching data for rs4652997...
# Saved rs4652997 to file.
# Fetching data for rs719769...
# Saved rs719769 to file.
# Fetching data for rs1023325...
# Saved rs1023325 to file.
# Fetching data for rs6698707...
# Saved rs6698707 to file.
# Fetching data for rs12043879...
# Saved rs12043879 to file.
# Fetching data for rs35285316...
# Saved rs35285316 to file.
# Fetching data for rs1414472...
# Saved rs1414472 to file.
# Fetching data for rs10914890...
# Saved rs10914890 to file.
# Fetching data for rs771410...
# Saved rs771410 to file.
# Fetching data for rs12128858...
# Saved rs12128858 to file.
# Fetching data for rs771404...
# Saved rs771404 to file.
# Fetching data for rs7512138...
# Saved rs7512138 to file.
# Fetching data for rs10799032...
# Saved rs10799032 to file.
# Fetching data for rs771401...
# Saved rs771401 to file.
# Fetching data for rs6425885...
# Saved rs6425885 to file.
# Fetching data for rs7535511...
# Saved rs7535511 to file.
# Fetching data for rs10914894...
# Saved rs10914894 to file.
# Fetching data for rs10914896...
# Saved rs10914896 to file.
# Fetching data for rs1414470...
# Saved rs1414470 to file.
# Fetching data for rs771390...
# Saved rs771390 to file.
# Fetching data for rs4653013...
# Saved rs4653013 to file.
# Fetching data for rs6704508...
# Saved rs6704508 to file.
# Fetching data for rs12130968...
# Saved rs12130968 to file.
# Fetching data for rs10914912...
# Saved rs10914912 to file.
# Fetching data for rs10914915...
# Saved rs10914915 to file.
# Fetching data for rs1361675...
# Saved rs1361675 to file.
# Fetching data for rs6669315...
# Saved rs6669315 to file.
# Fetching data for rs72652023...
# Saved rs72652023 to file.
# Fetching data for rs1342160...
# Saved rs1342160 to file.
# Fetching data for rs4652836...
# Saved rs4652836 to file.
# Fetching data for rs10799047...
# Saved rs10799047 to file.
# Fetching data for rs10914926...
# Saved rs10914926 to file.
# Fetching data for rs6695784...
# Saved rs6695784 to file.
# Fetching data for rs6660749...
# Saved rs6660749 to file.
# Fetching data for rs2359229...
# Saved rs2359229 to file.
# Fetching data for rs12064632...
# Saved rs12064632 to file.
# Fetching data for rs2049420...
# Error fetching data for rs2049420: HTTP Error 400: Bad Request
# Saved rs2049420 to file.
# Fetching data for rs2140682...
# Saved rs2140682 to file.
# Fetching data for rs12117975...
# Saved rs12117975 to file.
# Fetching data for rs12565280...
# Saved rs12565280 to file.
# Fetching data for rs17380703...
# Saved rs17380703 to file.
# Fetching data for rs705197...
# Saved rs705197 to file.
# Fetching data for rs2294193...
# Saved rs2294193 to file.
# Fetching data for rs732699...
# Saved rs732699 to file.
# Fetching data for rs2092028...
# Saved rs2092028 to file.
# Fetching data for rs7530700...
# Saved rs7530700 to file.
# Fetching data for rs6693232...
# Saved rs6693232 to file.
# Fetching data for rs2294191...
# Saved rs2294191 to file.
# Fetching data for rs2294190...
# Saved rs2294190 to file.
# Fetching data for rs2294189...
# Saved rs2294189 to file.
# Fetching data for rs12750334...
# Saved rs12750334 to file.
# Fetching data for rs2294188...
# Saved rs2294188 to file.
# Fetching data for rs4653029...
# Saved rs4653029 to file.
# Fetching data for rs1883109...
# Saved rs1883109 to file.
# Fetching data for rs17385253...
# Saved rs17385253 to file.
# Fetching data for rs12048760...
# Saved rs12048760 to file.
# Fetching data for rs7533470...
# Saved rs7533470 to file.
# Fetching data for rs2142534...
# Saved rs2142534 to file.
# Fetching data for rs4653032...
# Saved rs4653032 to file.
# Fetching data for rs10799058...
# Saved rs10799058 to file.
# Fetching data for rs6681948...
# Saved rs6681948 to file.
# Fetching data for rs4653036...
# Saved rs4653036 to file.
# Fetching data for rs2075933...
# Saved rs2075933 to file.
# Fetching data for rs12035126...
# Saved rs12035126 to file.
# Fetching data for rs1016090...
# Saved rs1016090 to file.
# Fetching data for rs1033371...
# Saved rs1033371 to file.
# Fetching data for rs7544781...
# Saved rs7544781 to file.
# Fetching data for rs4653042...
# Saved rs4653042 to file.
# Fetching data for rs7549758...
# Saved rs7549758 to file.
# Fetching data for rs798076...
# Saved rs798076 to file.
# Fetching data for rs798074...
# Saved rs798074 to file.
# Fetching data for rs798069...
# Saved rs798069 to file.
# Fetching data for rs10914958...
# Saved rs10914958 to file.
# Fetching data for rs41416648...
# Saved rs41416648 to file.
# Fetching data for rs798066...
# Saved rs798066 to file.
# Fetching data for rs72654119...
# Saved rs72654119 to file.
# Fetching data for rs10799062...
# Saved rs10799062 to file.
# Fetching data for rs12145038...
# Saved rs12145038 to file.
# Fetching data for rs3905173...
# Saved rs3905173 to file.
# Fetching data for rs3845481...
# Saved rs3845481 to file.
# Fetching data for rs2359106...
# Saved rs2359106 to file.
# Fetching data for rs3845483...
# Saved rs3845483 to file.
# Fetching data for rs3856132...
# Saved rs3856132 to file.
# Fetching data for rs4652841...
# Saved rs4652841 to file.
# Fetching data for rs12027125...
# Saved rs12027125 to file.
# Fetching data for rs6694043...
# Saved rs6694043 to file.
# Fetching data for rs1539374...
# Saved rs1539374 to file.
# Fetching data for rs10493058...
# Saved rs10493058 to file.
# Fetching data for rs10914967...
# Saved rs10914967 to file.
# Fetching data for rs6657583...
# Saved rs6657583 to file.
# Fetching data for rs10737381...
# Saved rs10737381 to file.
# Fetching data for rs1418483...
# Saved rs1418483 to file.
# Fetching data for rs12136079...
# Saved rs12136079 to file.
# Fetching data for rs6425900...
# Saved rs6425900 to file.
# Fetching data for rs947671...
# Saved rs947671 to file.
# Fetching data for rs6661959...
# Saved rs6661959 to file.
# Fetching data for rs6665029...
# Saved rs6665029 to file.
# Fetching data for rs6677231...
# Saved rs6677231 to file.
# Fetching data for rs6668930...
# Saved rs6668930 to file.
# Fetching data for rs6671294...
# Saved rs6671294 to file.
# Fetching data for rs7530276...
# Saved rs7530276 to file.
# Fetching data for rs10914983...
# Saved rs10914983 to file.
# Fetching data for rs12074036...
# Saved rs12074036 to file.
# Fetching data for rs1342476...
# Saved rs1342476 to file.
# Fetching data for rs10914986...
# Saved rs10914986 to file.
# Fetching data for rs728448...
# Saved rs728448 to file.
# Fetching data for rs728447...
# Saved rs728447 to file.
# Fetching data for rs10914987...
# Saved rs10914987 to file.
# Fetching data for rs10914988...
# Saved rs10914988 to file.
# Fetching data for rs12090691...
# Saved rs12090691 to file.
# Fetching data for rs1886340...
# Saved rs1886340 to file.
# Fetching data for rs4653061...
# Saved rs4653061 to file.
# Fetching data for rs12024207...
# Saved rs12024207 to file.
# Fetching data for rs7544557...
# Saved rs7544557 to file.
# Fetching data for rs716289...
# Saved rs716289 to file.
# Fetching data for rs12059222...
# Saved rs12059222 to file.
# Fetching data for rs2093880...
# Saved rs2093880 to file.
# Fetching data for rs6425904...
# Saved rs6425904 to file.
# Fetching data for rs7548924...
# Saved rs7548924 to file.
# Fetching data for rs12132123...
# Saved rs12132123 to file.
# Fetching data for rs612353...
# Saved rs612353 to file.
# Fetching data for rs4652852...
# Saved rs4652852 to file.
# Fetching data for rs491000...
# Saved rs491000 to file.
# Fetching data for rs506361...
# Saved rs506361 to file.
# Fetching data for rs6425908...
# Saved rs6425908 to file.
# Fetching data for rs9787098...
# Saved rs9787098 to file.
# Fetching data for rs509788...
# Saved rs509788 to file.
# Fetching data for rs10915010...
# Saved rs10915010 to file.
# Fetching data for rs912537...
# Saved rs912537 to file.
# Fetching data for rs12024912...
# Saved rs12024912 to file.
# Fetching data for rs12142734...
# Saved rs12142734 to file.
# Fetching data for rs491257...
# Saved rs491257 to file.
# Fetching data for rs1177663...
# Saved rs1177663 to file.
# Fetching data for rs12136236...
# Saved rs12136236 to file.
# Fetching data for rs10915021...
# Saved rs10915021 to file.
# Fetching data for rs4320749...
# Saved rs4320749 to file.
# Fetching data for rs1336625...
# Saved rs1336625 to file.
# Fetching data for rs10493063...
# Saved rs10493063 to file.
# Fetching data for rs601908...
# Saved rs601908 to file.
# Fetching data for rs542916...
# Saved rs542916 to file.
# Fetching data for rs684524...
# Saved rs684524 to file.
# Fetching data for rs10489658...
# Saved rs10489658 to file.
# Fetching data for rs1741953...
# Saved rs1741953 to file.
# Fetching data for rs55866306...
# Saved rs55866306 to file.
# Fetching data for rs2145388...
# Saved rs2145388 to file.
# Fetching data for rs1764406...
# Saved rs1764406 to file.
# Fetching data for rs666919...
# Saved rs666919 to file.
# Fetching data for rs1884999...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 32
#      30 if "snp_info" not in row or not row["snp_info"]:  # Skip if already fetched
#      31     print(f"Fetching data for {row['rsid']}...")
# ---> 32     row["snp_info"] = fetch_snp_info(row["rsid"])
#      33     writer.writerow(row)
#      34     print(f"Saved {row['rsid']} to file.")
#
# Cell In[6], line 8, in fetch_snp_info(rsid)
#       6 try:
#       7     Entrez.email = "ilcardenas26@gmail.com"
# ----> 8     handle = Entrez.efetch(db="snp", id=rsid, rettype="docset", retmode="text")
#       9     time.sleep(3)
#      10     return handle.read()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\Bio\Entrez\__init__.py:201, in efetch(db, **keywords)
#     199 variables.update(keywords)
#     200 request = _build_request(cgi, variables)
# --> 201 return _open(request)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\Bio\Entrez\__init__.py:634, in _open(request)
#     632 for i in range(max_tries):
#     633     try:
# --> 634         handle = urlopen(request)
#     635     except HTTPError as exception:
#     636         # Reraise if the final try fails
#     637         if i >= max_tries - 1:
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File c:\ProgramData\anaconda3\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
# -> 1348     r = h.getresponse()
#    1349 except:
#    1350     h.close()
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\ProgramData\anaconda3\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File c:\ProgramData\anaconda3\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File c:\ProgramData\anaconda3\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import sqlite3
import pandas as pd
import time
from Bio import Entrez
import multiprocessing
from multiprocessing import Pool, cpu_count
from tqdm import tqdm


def fetch_snp_info(rsid):
    """
    Fetch SNP info using NCBI Entrez API for a given rsID.
    """
    try:
        Entrez.email = "ilcardenas26@gmail.com"
        # print(f"Processing rsID: {rsid}")  # Log the rsID being processed
        handle = Entrez.efetch(db="snp", id=rsid, rettype="docset", retmode="text")
        time.sleep(1)  # Respect API rate limits
        return rsid, handle.read()

    except Exception as e:
        print(f"Error fetching data for {rsid}: {e}")
        if "Error 400" in e:
            return rsid, "No data found in SNP database."
        else: 
            return rsid, None


def process_chunk(rsid_chunk):
    """
    Process a chunk of rsIDs by fetching SNP info.
    """
    results = []
    for rsid in rsid_chunk:
        results.append(fetch_snp_info(rsid))
    return results


def update_database(db_file, results):
    """
    Update the SQLite database with the fetched SNP info.
    """
    conn = sqlite3.connect(db_file)
    print("Connected to DB")
    cursor = conn.cursor()
    print("created cursor")
    for rsid, snp_info in results:
        print(rsid, snp_info)
        cursor.execute("UPDATE snp_data SET snp_info = ? WHERE rsid = ?", (snp_info, rsid))
        print('Item updated')
    conn.commit()
    conn.close()


def main():
    # Input and database setup
    input_file = "AncestryDNA.txt"
    db_file = "snp_data.db"

    # Create SQLite database and load data if not already present
    # conn = sqlite3.connect(db_file)
    # df = pd.read_csv(input_file, delimiter="\t")
    # df.to_sql("snp_data", conn, if_exists="replace", index=False)
    
    # # Add the 'snp_info' column if it doesn't exist
    # if 'snp_info' not in df.columns:
    #     df['snp_info'] = None

    # # Save to the database
    # df.to_sql("snp_data", conn, if_exists="replace", index=False)
    # conn.close()
    

    # Fetch all rsIDs with missing SNP info
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    # cursor.execute(("CREATE INDEX indexing ON snp_data (rsid);"))
    cursor.execute("SELECT rsid FROM snp_data WHERE snp_info IS NULL")
    rsid_list = [row[0] for row in cursor.fetchall()]
    print("RSID List created")
    print (rsid_list[:5])
    conn.close()

    # Divide rsIDs into chunks for multiprocessing
    
    print("Starting chunking")
    num_processes = min(cpu_count(), len(rsid_list))  # Use as many processes as available cores
    # chunk_size = len(rsid_list) // num_processes + 1
    chunk_size = 10
   
    rsid_chunks = [rsid_list[i:i + chunk_size] for i in range(0, len(rsid_list), chunk_size)]
    print("Chunks: ", len(rsid_chunks))

    print("Finished Chuncking")
    return rsid_chunks, rsid_list, num_processes
if __name__ == "__main__":
    rsid_chuncks, rsid_list, num_procesess = main()
# Out:
# RSID List created
# ['rs2274328', 'rs2274330', 'rs17032907', 'rs3765968', 'rs3765966']
# Starting chunking
# Chunks:  67500
# Finished Chuncking

# %%
rsid_chuncks, rsid_list, num_procesess

# %%
db_file = "snp_data.db"
def printtest(id):
        print(id)
        
conn = sqlite3.connect(db_file)
print("Connected to DB")
cursor = conn.cursor()
print("created cursor")


             
with Pool(12) as pool:
        for segment in rsid_chuncks:
                for i in tqdm(range(0,len(rsid_chuncks)), total=len(rsid_chuncks), desc="Progress"):              
                        for item in segment:
                                rsid, snp_info = fetch_snp_info(item)
                                # item = fetch_snp_info(row["rsid"])
                                cursor.execute("UPDATE snp_data SET snp_info = ? WHERE rsid = ?", (snp_info, rsid))
                                conn.commit()
                               
conn.close()              

    # # Save the final updated data to CSV
    # conn = sqlite3.connect(db_file)
    # df_updated = pd.read_sql("SELECT * FROM snp_data", conn)
    # # df_updated.to_csv("snp_info_output.csv", index=False)
    # conn.close()

print("Processing complete. Data saved to snp_info_output.csv.")
# Out:
# Connected to DB
# created cursor
# Progress:   0%|          | 1/67500 [00:24<453:36:19, 24.19s/it]
# Error fetching data for rs2274328: HTTP Error 400: Bad Request
# Progress:   0%|          | 17/67500 [06:27<428:21:56, 22.85s/it]
# Error fetching data for rs2274330: HTTP Error 400: Bad Request
# Progress:   0%|          | 25/67500 [09:32<435:13:36, 23.22s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   0%|          | 35/67500 [13:16<430:15:58, 22.96s/it]
# Error fetching data for rs12021597: HTTP Error 400: Bad Request
# Progress:   0%|          | 61/67500 [23:11<425:11:54, 22.70s/it]
# Error fetching data for rs17032912: HTTP Error 400: Bad Request
# Progress:   0%|          | 71/67500 [27:02<437:48:24, 23.37s/it]
# Error fetching data for rs2274330: HTTP Error 400: Bad Request
# Progress:   0%|          | 97/67500 [36:57<428:55:16, 22.91s/it]
# Error fetching data for rs2274330: HTTP Error 400: Bad Request
# Progress:   0%|          | 107/67500 [41:26<592:27:21, 31.65s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   0%|          | 137/67500 [53:21<429:33:04, 22.96s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   0%|          | 160/67500 [1:02:30<414:41:27, 22.17s/it]
# Error fetching data for rs2274332: HTTP Error 400: Bad Request
# Progress:   0%|          | 176/67500 [1:08:25<412:13:40, 22.04s/it]
# Error fetching data for rs2274332: HTTP Error 400: Bad Request
# Progress:   0%|          | 177/67500 [1:08:46<408:49:58, 21.86s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   0%|          | 181/67500 [1:10:18<422:53:23, 22.61s/it]
# Error fetching data for rs17389460: HTTP Error 400: Bad Request
# Progress:   0%|          | 189/67500 [1:13:23<419:48:05, 22.45s/it]
# Error fetching data for rs2274332: HTTP Error 400: Bad Request
# Progress:   0%|          | 203/67500 [1:18:38<425:34:47, 22.77s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   0%|          | 211/67500 [1:21:35<412:26:49, 22.07s/it]
# Error fetching data for rs2274330: HTTP Error 400: Bad Request
# Progress:   0%|          | 263/67500 [1:41:36<450:21:19, 24.11s/it]
# Error fetching data for rs17032907: HTTP Error 400: Bad Request
# Progress:   0%|          | 270/67500 [1:44:13<422:36:30, 22.63s/it]
# Error fetching data for rs17389460: HTTP Error 400: Bad Request
# Progress:   0%|          | 283/67500 [1:49:06<420:00:31, 22.49s/it]
# Error fetching data for rs2274328: HTTP Error 400: Bad Request
# Progress:   0%|          | 287/67500 [1:50:33<409:29:10, 21.93s/it]
# Error fetching data for rs17032907: HTTP Error 400: Bad Request
# Progress:   0%|          | 308/67500 [1:58:25<408:08:39, 21.87s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   0%|          | 317/67500 [2:01:44<414:11:42, 22.19s/it]
# Error fetching data for rs3765966: HTTP Error 400: Bad Request
# Error fetching data for rs17389460: HTTP Error 400: Bad Request
# Progress:   1%|          | 352/67500 [2:14:47<424:38:46, 22.77s/it]
# Error fetching data for rs3765966: HTTP Error 400: Bad Request
# Progress:   1%|          | 375/67500 [2:23:24<419:43:25, 22.51s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   1%|          | 430/67500 [2:44:27<417:50:43, 22.43s/it]
# Error fetching data for rs17032907: HTTP Error 400: Bad Request
# Progress:   1%|          | 470/67500 [2:59:26<418:27:22, 22.47s/it]
# Error fetching data for rs2274328: HTTP Error 400: Bad Request
# Progress:   1%|          | 582/67500 [3:40:54<402:40:56, 21.66s/it]
# Error fetching data for rs2274332: HTTP Error 400: Bad Request
# Progress:   1%|          | 628/67500 [3:57:55<414:07:15, 22.29s/it]
# Error fetching data for rs3765966: HTTP Error 400: Bad Request
# Progress:   1%|          | 630/67500 [3:58:40<416:04:39, 22.40s/it]
# Error fetching data for rs2274330: HTTP Error 400: Bad Request
# Progress:   1%|          | 757/67500 [4:45:27<429:25:39, 23.16s/it]
# Error fetching data for rs17032912: HTTP Error 400: Bad Request
# Progress:   1%|          | 783/67500 [4:55:06<419:38:39, 22.64s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   1%|          | 789/67500 [4:57:15<401:36:40, 21.67s/it]
# Error fetching data for rs3765968: HTTP Error 400: Bad Request
# Progress:   1%|          | 801/67500 [5:02:01<419:09:01, 22.62s/it]
# Error fetching data for rs17389460: IncompleteRead(3520 bytes read)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\http\client.py:579, in HTTPResponse._get_chunk_left(self)
#     578 try:
# --> 579     chunk_left = self._read_next_chunk_size()
#     580 except ValueError:
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:546, in HTTPResponse._read_next_chunk_size(self)
#     545 try:
# --> 546     return int(line, 16)
#     547 except ValueError:
#     548     # close the connection as protocol synchronisation is
#     549     # probably lost
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\http\client.py:595, in HTTPResponse._read_chunked(self, amt)
#     594 try:
# --> 595     while (chunk_left := self._get_chunk_left()) is not None:
#     596         if amt is not None and amt <= chunk_left:
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:581, in HTTPResponse._get_chunk_left(self)
#     580 except ValueError:
# --> 581     raise IncompleteRead(b'')
#     582 if chunk_left == 0:
#     583     # last chunk: 1*("0") [ chunk-extension ] CRLF
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# The above exception was the direct cause of the following exception:
#
# IncompleteRead                            Traceback (most recent call last)
# Cell In[5], line 19, in fetch_snp_info(rsid)
#      18     time.sleep(1)  # Respect API rate limits
# ---> 19     return rsid, handle.read()
#      21 except Exception as e:
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:473, in HTTPResponse.read(self, amt)
#     472 if self.chunked:
# --> 473     return self._read_chunked(amt)
#     475 if amt is not None:
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:607, in HTTPResponse._read_chunked(self, amt)
#     606 except IncompleteRead as exc:
# --> 607     raise IncompleteRead(b''.join(value)) from exc
#
# IncompleteRead: IncompleteRead(3520 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 16
#      14 for i in tqdm(range(0,len(rsid_chuncks)), total=len(rsid_chuncks), desc="Progress"):
#      15         for item in segment:
# ---> 16                 rsid, snp_info = fetch_snp_info(item)
#      17                 # item = fetch_snp_info(row["rsid"])
#      18                 cursor.execute("UPDATE snp_data SET snp_info = ? WHERE rsid = ?", (snp_info, rsid))
#
# Cell In[5], line 23, in fetch_snp_info(rsid)
#      21 except Exception as e:
#      22     print(f"Error fetching data for {rsid}: {e}")
# ---> 23     if "Error 400" in e:
#      24         return rsid, "No data found in SNP database."
#      25     else:
#
# TypeError: argument of type 'IncompleteRead' is not iterable
